# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from Day4LLMCalling.callLlms import Llms

# %%
Llms.callOpenRouterModel('how many prompts did I give including this?',system_prompt='Give me 7 word response', model='openai/gpt-oss-120b:free')
# Out:
# {'model': [{'role': 'system', 'content': ''}], 'openai/gpt-oss-120b:free': [{'role': 'system', 'content': 'Give me 7 word response'}, {'role': 'user', 'content': 'Hi'}, {'role': 'assistant', 'content': 'Hello! How can I assist you?'}, {'role': 'user', 'content': 'Hello'}, {'role': 'assistant', 'content': 'Hello! How can I help you today?'}, {'role': 'user', 'content': 'how many prompts did I give including this?'}], 'qwen/qwen3.6-plus:free': [{'role': 'system', 'content': 'Give me 7 word response'}, {'role': 'user', 'content': 'Hello'}, {'role': 'assistant', 'content': 'Hello! How can I assist you today?'}, {'role': 'user', 'content': 'What is your model?'}]}
# ...
