# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from Day4LLMCalling.callLlms import Llms

# %%
Llms.callOpenRouterModel('hi. Give me a 5 word response.')
# Out:
# 'Hello! How may I help?'
