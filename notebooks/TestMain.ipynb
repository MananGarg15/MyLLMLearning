# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from Day4LLMCalling.callLlms import Llms

# %%
Llms.callOpenRouterModel('Hi',system_prompt='Give me at most 5 word response', model='openai/gpt-oss-120b:free')
# Out:
# {'model': [{'role': 'system', 'content': ''}]}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Llms.callOpenRouterModel('Hi',system_prompt='Give me at most 5 word response', model='openai/gpt-oss-120b:free')
#
# File c:\Users\PGCP-AI\projects\MyLLMLearning\Day4LLMCalling\callLlms.py:32, in Llms.callOpenRouterModel(message, new, system_prompt, response_format, markdown, model)
#      30     else:
#      31         mSeries.openRouterModelMessages[model] = system_message
# ---> 32     print(mSeries.openRouterModelMessages[model][0])
#      34 response = Llms.openRouter.chat.completions.create(model=model,messages=messages, response_format={"type":response_format})
#      35 result = response.choices[0].message.content
#
# KeyError: 0
