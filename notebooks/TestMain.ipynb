# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from Day4LLMCalling.callLlms import Llms

# %%
Llms.callGemini('Hi. What is your model?',system_prompt='give me less than 15 word responses')
# Out:
# 'I am a large language model, trained by Google.'

# %%
Llms.callOllama('Hi. What is your model?',system_prompt='give me less than 15 word responses')
# Out:
# {'gemini-3-flash-preview': [{'role': 'system', 'content': 'give me less than 15 word responses'}, {'role': 'user', 'content': 'Hi. What is your model?'}, {'role': 'assistant', 'content': 'I am a large language model, trained by Google.'}], 'gemma4:e4b': [{'role': 'system', 'content': 'give me less than 15 word responses'}, {'role': 'user', 'content': 'Hi. What is your model?'}, {'role': 'user', 'content': 'Hi. What is your model?'}, {'role': 'assistant', 'content': 'I am Gemma 4, an open weights model.'}, {'role': 'user', 'content': 'Hi. What is your model?'}, {'role': 'assistant', 'content': 'I am Gemma 4, an open weights model.'}], 'qwen/qwen3.6-plus:free': [{'role': 'system', 'content': 'give me less than 15 word responses'}, {'role': 'user', 'content': 'Hi. What is your model?'}], 'openai/gpt-oss-120b:free': [{'role': 'system', 'content': 'give me less than 15 word responses'}, {'role': 'user', 'content': 'Hi. What is your model?'}, {'role': 'assistant', 'content': "I'm GPT‑4, an
# ...

# %%
Llms.callOpenRouterModel('Hi. What is your model?',system_prompt='give me less than 15 word responses', model='openai/gpt-oss-120b:free')
# Out:
# "I'm GPT‑4, an OpenAI large language model."

# %%
word = Llms.callModel('give me a random word',source='ollama')

# %%
word
# Out:
# 'Nebulous'
