# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
import json
from Day5CompanyBrochure.RelevantLinks import getRelevantLinks
from Day5CompanyBrochure.WebsiteContent import getWebsiteContent
from Day5CompanyBrochure.Brochure import getBrochure

# %%
brochure = getBrochure('https://www.foss.systems/catalog/',company_name='foss systems')
# Out:
# selecting relevant links from https://www.foss.systems/catalog/ by calling Llama
# Found 10 relevant links
# Generated Brochure Content.
# Creating brochure for foss systems...

# %%
from IPython.display import display

display(brochure)
# Out:
# # Empowering Digital Freedom: The FOSS.systems Corporate Brochure
#
# ### **Company Overview: The Central Hub for Open Source**
#
# **FOSS.systems** is a premier digital platform dedicated to the collection, categorization, and preservation of Free and Open Source Software (FOSS). In an era where digital systems underpin every aspect of human life, we believe that software should be a public good. Our mission is to provide the comprehensive infrastructure necessary to discover, explore, and connect with the world’s largest collection of FOSS projects.
#
# At its core, FOSS.systems is more than a directory; it is a vital repository for the "Libre" philosophy. We champion the four fundamental rights of digital citizens:
# *   **Use:** The freedom to run programs for any purpose.
# *   **Modify:** The freedom to study and change software to meet specific needs.
# *   **Share:** The freedom to redistribute copies to help others.
# *   **Distribute:** The freedom to release improvements to the public.
#
# By organizing the global FOSS ecosystem into a structured, searchable, and interconnected database, FOSS.systems serves as the foundational building block for digital communities worldwide.
#
# ---
#
# ### **Products & Services: A Comprehensive Digital Ecosystem**
#
# FOSS.systems offers a sophisticated suite of tools designed for developers, system administrators, and privacy-conscious consumers. Our platform currently hosts over **1,500 projects** across more than **25 categories**, updated daily to ensure data freshness.
#
# **The FOSS Catalog**
# Our flagship product is a high-performance, searchable catalog that allows users to find software solutions across various domains:
# *   **Web Applications:** Over 200 self-hosted tools, CMS platforms, and productivity suites (e.g., Nextcloud).
# *   **Mobile Applications:** Privacy-focused tools and Android apps sourced from F-Droid.
# *   **Development Tools:** A curated selection of programming languages (Python), frameworks, and IDEs.
# *   **System Administration:** Infrastructure tools, Docker containerization, and server management solutions.
# *   **Security & Privacy:** Essential encryption tools, VPNs, and password managers.
# *   **Media & Entertainment:** Open-source games and streaming tools for the creative community.
#
# **The Tech Stack Explorer**
# Beyond simple listings, FOSS.systems allows users to explore how different projects interact. Our "Tech Stack" feature maps relationships and dependencies, providing a clear roadmap for building complex systems entirely on open-source foundations.
#
# **The Library and Research Hub**
# The platform includes a dedicated library and development blog that documents the evolution of FOSS. We provide deep dives into "Federated Architecture," moving beyond traditional static catalogs to create a dynamic, interconnected web of software metadata.
#
# ---
#
# ### **Investor Highlights: Scalability and Strategic Value**
#
# For investors, FOSS.systems represents a unique opportunity to support the essential infrastructure of the modern digital economy. As enterprises and governments increasingly pivot toward **Digital Sovereignty**, the demand for verified, well-documented open-source alternatives to proprietary software is at an all-time high.
#
# **Key Investment Pillars:**
# *   **Aggregated Data Intelligence:** We aggregate and normalize data from diverse sources including GitHub, F-Droid, YunoHost, and various "Awesome Lists." This creates a proprietary, high-value dataset of the global FOSS landscape.
# *   **Strategic Growth Statistics:** With over 1,500 projects and 50+ technologies already indexed, our database is expanding rapidly through automated verification and community validation.
# *   **Federated Architecture Vision:** We are moving toward a decentralized, federated model of software cataloging. This innovation positions FOSS.systems as a leader in the next generation of web architecture, moving away from centralized, siloed information hubs.
# *   **Automated Data Freshness:** Our system is built for scale, featuring daily updates and automated metadata verification to ensure the platform remains the most reliable source of truth in the industry.
#
# ---
#
# ### **Careers & Culture: Building the Future of Software**
#
# At FOSS.systems, we are looking for visionaries, developers, and data enthusiasts who believe that code is a form of social architecture. Working with us means contributing to a project that directly impacts the digital freedom of millions.
#
# **Why Join FOSS.systems?**
# *   **Mission-Driven Work:** Every line of code you write and every project you catalog helps build a free digital world. We are not just building a product; we are safeguarding a movement.
# *   **A Culture of Openness:** We practice what we preach. Our internal culture is rooted in the same principles as FOSS: transparency, collaboration, and the freedom to experiment.
# *   **Tech-Forward Environment:** Work with the latest in metadata management, federated systems, and the Gantry Framework. Our contributors help map complex technology stacks and define how the world discovers new software.
# *   **Global Impact:** Your work will assist developers in emerging markets, privacy advocates in restrictive environments, and IT professionals in world-class enterprises.
#
# **How to Contribute:**
# We are always seeking talent to help grow the catalog, improve data metadata, and map the intricate relationships between global FOSS projects. Whether you are a developer looking to submit a project or a data scientist interested in relationship mapping, there is a place for you at FOSS.systems.
#
# ---
#
# ### **Contact & Connection**
#
# Join the revolution and help us build the ultimate resource for Free and Open Source Software. Together, we can ensure that the digital foundations of the future remain open, accessible, and free for all.
#
# *   **Explore the Catalog:** [www.foss.systems/catalog](https://www.foss.systems/catalog)
# *   **Read Our Vision:** [www.foss.systems/blog](https://www.foss.systems/blog)
# *   **Contribute Today:** [www.foss.systems/contribute](https://www.foss.systems/contribute)
#
# **FOSS.systems – The Central Hub for a Free Digital World.**

# %%
from IPython.display import display

display(brochure)
# Out:
# **Company Overview**
#
# Welcome to FOSS Systems, a leading provider of Free and Open Source Software (FOSS) solutions. Our mission is to bridge the gap between local innovation and global knowledge, empowering developers and organizations to make informed decisions about technology adoption.
#
# **Products & Services**
#
# * **FOSS Catalog**: Discover over 1,500 free and open source software projects across all categories and platforms.
# * **Development Tools**: Programming languages, frameworks, IDEs, version control, and development environments.
# * **System Administration**: Infrastructure tools, monitoring systems, backup solutions, and server management.
# * **Security & Privacy**: Encryption tools, VPNs, password managers, and privacy-focused applications.
# * **Entertainment & Media**: Games, media players, streaming tools, and creative applications.
#
# **Featured Projects**
#
# * **Docker**: A containerization platform that revolutionized application deployment.
# * **Firefox**: An open-source web browser focused on privacy and user control.
# * **Python**: A versatile programming language powering web apps, AI, and scientific computing.
# * **Nextcloud**: A self-hosted productivity platform with file sync, calendar, and collaboration.
#
# **Investor Highlights**
#
# We are a rapidly growing company with a strong focus on innovation and community engagement. Our unique federated architecture vision aims to transform the FOSS landscape into a seamless bridge between local innovation and global knowledge.
#
# ### **Data and Statistics**
#
# * 1,500+ Total Projects
# * 25+ Categories
# * 50+ Technologies
# * 5+ Data Sources
#
# **Careers & Culture**
#
# We are committed to fostering a culture of community engagement, collaboration, and continuous learning. Join our team of passionate individuals who share a vision for shaping the future of FOSS.
#
# ### **Get Involved**
#
# Help grow the catalog by submitting projects or contributing data. Contribute to improving project descriptions, categories, and metadata. Connect projects to map relationships, dependencies, and technology stacks.
#
# **Stay Up-to-Date**
#
# Follow us on social media or visit our blog for the latest news and insights into the world of FOSS.
