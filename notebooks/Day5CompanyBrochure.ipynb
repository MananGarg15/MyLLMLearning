# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from Day5CompanyBrochure.Brochure import getBrochure

# %%
getBrochure('https://www.foss.systems/catalog/',company_name='foss systems')
# Out:
# selecting relevant links from https://www.foss.systems/catalog/
# Found 19 relevant links
# Generated Brochure Content.
# Creating brochure for foss systems...

# %%
from IPython.display import display

display(brochure)
# Out:
# **FOSS Systems – The World’s Most Comprehensive Free & Open‑Source Software Catalog**
# *Connecting people, projects, and possibilities across the digital landscape.*
#
# ---
#
# ## **Company Overview**
# FOSS Systems is a global, community‑driven platform that aggregates, catalogs, and preserves **1,500+ Free & Open‑Source Software (FOSS) projects** across **25+ categories** and **50+ technologies**. Built on the belief that open software is the foundation of a free digital world, FOSS Systems serves as the central hub where developers, enterprises, investors, and enthusiasts can discover, evaluate, and contribute to the tools shaping tomorrow’s technology ecosystem.
#
# - **Mission:** Create a single, authoritative repository for every FOSS project—cataloged, described, and linked for easy discovery.
# - **Vision:** A world where free software underpins every digital interaction, empowering individuals and economies alike.
# - **Core Values:** Openness, collaboration, quality, and sustainable innovation.
#
# ---
#
# ## **Products & Services**
#
# ### 1. **FOSS Catalog**
# A searchable, filter‑rich directory of open‑source projects.
#
# | Feature | Benefit |
# |---------|---------|
# | **Advanced Search & Quick Filters** (Web Apps, Mobile, Development, System, Security, Entertainment) | Instantly locate the right tool for any use case. |
# | **Rich Project Metadata** (tags, tech stacks, dependencies, source pointers) | Enables rapid assessment of compatibility and maturity. |
# | **Category Browsing** – 200+ projects per major category | Provides depth without overwhelming users. |
# | **Daily Data Refresh** from F‑Droid, YunoHost, GitHub awesome‑lists, and community submissions | Guarantees up‑to‑date information. |
# | **Tech‑Stack Mapping** | Visualize how projects interconnect, simplify integration decisions. |
# | **Featured Projects** (Docker, Firefox, Python, Nextcloud) | Highlight industry‑leading solutions with proven impact. |
#
# ### 2. **Library & Knowledge Base**
# Curated documentation, tutorials, and case studies that help users:
#
# - Onboard new contributors.
# - Evaluate security and privacy implications.
# - Deploy and maintain solutions at scale.
#
# ### 3. **Community & Contribution Platform**
# Tools for the ecosystem to give back:
#
# - **Submit Projects** – Add missing software to the catalog.
# - **Improve Data** – Refine descriptions, tags, and metadata.
# - **Map Connections** – Define relationships, dependencies, and technology stacks.
#
# ### 4. **Federated Architecture Vision**
# A forward‑looking framework that moves beyond traditional, siloed catalogs:
#
# - **Distributed Data Sources** – Seamlessly integrates multiple upstream feeds.
# - **API‑First Access** – Enables partners, SaaS providers, and investors to embed catalog data into their own products.
# - **Open Governance** – Community‑validated quality controls and automated verification.
#
# ---
#
# ## **Investor Highlights**
#
# | Metric | Detail |
# |--------|--------|
# | **Scale** | 1,500+ projects, 25+ categories, 50+ technologies; the largest publicly‑available FOSS index. |
# | **Growth** | Daily ingestion from multiple sources; projected 30% YoY increase in catalog size. |
# | **Revenue Opportunities** | API licensing, premium analytics, enterprise integration services, sponsorship of featured projects. |
# | **Strategic Position** | Unique “central hub” that reduces discovery friction for enterprises adopting open‑source stacks—critical for cost‑reduction and compliance. |
# | **Sustainability** | Community‑driven model lowers operating costs; open‑source contributions ensure continual innovation. |
# | **Exit Potential** | Attractive acquisition target for cloud providers, DevOps platforms, or security vendors seeking a curated open‑source knowledge base. |
#
# ---
#
# ## **Careers & Culture**
#
# ### Why Join FOSS Systems?
# - **Impact‑First Work:** Directly shape the ecosystem that powers billions of devices and services worldwide.
# - **Remote‑First, Collaborative Culture:** Global teams united by shared values of openness and transparency.
# - **Continuous Learning:** Access to the latest open‑source projects, cutting‑edge tech stacks, and community events.
# - **Professional Growth:** Opportunities to lead product development, data engineering, community management, and business development.
#
# ### Open Positions (examples)
# - **Product Manager – Open‑Source Catalog** – Drive roadmap, partner integrations, and API strategy.
# - **Data Engineer – Knowledge Graphs** – Build relation‑mapping pipelines and enhance metadata quality.
# - **Community Lead – Contributor Engagement** – Grow and nurture the global contributor base.
# - **Security Analyst – FOSS Auditing** – Ensure cataloged projects meet high security & privacy standards.
#
# ### Our Culture in Action
# - **Hack Weeks** – Quarterly sprints where any team member can prototype new features.
# - **Open Governance** – Transparent decision‑making via public issue trackers and community voting.
# - **Diversity & Inclusion** – Active outreach to under‑represented groups in tech; scholarships for open‑source contributors.
#
# ---
#
# ## **Get Started with FOSS Systems**
#
# | Action | How |
# |--------|-----|
# | **Explore the Catalog** | Visit **[foss.systems/catalog](https://www.foss.systems/catalog)** and apply filters to find the perfect solution. |
# | **Read the Blog** | Stay current with trends and the **Federated Architecture Vision** at **[foss.systems/blog](https://www.foss.systems/blog)**. |
# | **Contribute** | Submit projects, improve data, or map connections via the **Contribute** portal. |
# | **Partner or License** | Contact the business development team for API access, data licensing, or sponsorship opportunities. |
# | **Join the Team** | Review open roles on the **Careers** page and become part of the open‑source revolution. |
#
# ---
#
# ### **Connect with Us**
# - **Website:** https://www.foss.systems
# - **Email:** info@foss.systems
# - **Community Forum:** Linked from the website footer
# - **Social:** Follow @FOSSsystems on Twitter, LinkedIn, and Mastodon for updates.
#
# ---
#
# *FOSS Systems – Empowering a free digital future, one open‑source project at a time.*

# %%
from IPython.display import display

display(brochure)
# Out:
# **FOSS Systems – The World’s Most Comprehensive Free & Open‑Source Software Catalog**
# *Connecting people, projects, and possibilities across the digital landscape.*
#
# ---
#
# ## **Company Overview**
# FOSS Systems is a global, community‑driven platform that aggregates, catalogs, and preserves **1,500+ Free & Open‑Source Software (FOSS) projects** across **25+ categories** and **50+ technologies**. Built on the belief that open software is the foundation of a free digital world, FOSS Systems serves as the central hub where developers, enterprises, investors, and enthusiasts can discover, evaluate, and contribute to the tools shaping tomorrow’s technology ecosystem.
#
# - **Mission:** Create a single, authoritative repository for every FOSS project—cataloged, described, and linked for easy discovery.
# - **Vision:** A world where free software underpins every digital interaction, empowering individuals and economies alike.
# - **Core Values:** Openness, collaboration, quality, and sustainable innovation.
#
# ---
#
# ## **Products & Services**
#
# ### 1. **FOSS Catalog**
# A searchable, filter‑rich directory of open‑source projects.
#
# | Feature | Benefit |
# |---------|---------|
# | **Advanced Search & Quick Filters** (Web Apps, Mobile, Development, System, Security, Entertainment) | Instantly locate the right tool for any use case. |
# | **Rich Project Metadata** (tags, tech stacks, dependencies, source pointers) | Enables rapid assessment of compatibility and maturity. |
# | **Category Browsing** – 200+ projects per major category | Provides depth without overwhelming users. |
# | **Daily Data Refresh** from F‑Droid, YunoHost, GitHub awesome‑lists, and community submissions | Guarantees up‑to‑date information. |
# | **Tech‑Stack Mapping** | Visualize how projects interconnect, simplify integration decisions. |
# | **Featured Projects** (Docker, Firefox, Python, Nextcloud) | Highlight industry‑leading solutions with proven impact. |
#
# ### 2. **Library & Knowledge Base**
# Curated documentation, tutorials, and case studies that help users:
#
# - Onboard new contributors.
# - Evaluate security and privacy implications.
# - Deploy and maintain solutions at scale.
#
# ### 3. **Community & Contribution Platform**
# Tools for the ecosystem to give back:
#
# - **Submit Projects** – Add missing software to the catalog.
# - **Improve Data** – Refine descriptions, tags, and metadata.
# - **Map Connections** – Define relationships, dependencies, and technology stacks.
#
# ### 4. **Federated Architecture Vision**
# A forward‑looking framework that moves beyond traditional, siloed catalogs:
#
# - **Distributed Data Sources** – Seamlessly integrates multiple upstream feeds.
# - **API‑First Access** – Enables partners, SaaS providers, and investors to embed catalog data into their own products.
# - **Open Governance** – Community‑validated quality controls and automated verification.
#
# ---
#
# ## **Investor Highlights**
#
# | Metric | Detail |
# |--------|--------|
# | **Scale** | 1,500+ projects, 25+ categories, 50+ technologies; the largest publicly‑available FOSS index. |
# | **Growth** | Daily ingestion from multiple sources; projected 30% YoY increase in catalog size. |
# | **Revenue Opportunities** | API licensing, premium analytics, enterprise integration services, sponsorship of featured projects. |
# | **Strategic Position** | Unique “central hub” that reduces discovery friction for enterprises adopting open‑source stacks—critical for cost‑reduction and compliance. |
# | **Sustainability** | Community‑driven model lowers operating costs; open‑source contributions ensure continual innovation. |
# | **Exit Potential** | Attractive acquisition target for cloud providers, DevOps platforms, or security vendors seeking a curated open‑source knowledge base. |
#
# ---
#
# ## **Careers & Culture**
#
# ### Why Join FOSS Systems?
# - **Impact‑First Work:** Directly shape the ecosystem that powers billions of devices and services worldwide.
# - **Remote‑First, Collaborative Culture:** Global teams united by shared values of openness and transparency.
# - **Continuous Learning:** Access to the latest open‑source projects, cutting‑edge tech stacks, and community events.
# - **Professional Growth:** Opportunities to lead product development, data engineering, community management, and business development.
#
# ### Open Positions (examples)
# - **Product Manager – Open‑Source Catalog** – Drive roadmap, partner integrations, and API strategy.
# - **Data Engineer – Knowledge Graphs** – Build relation‑mapping pipelines and enhance metadata quality.
# - **Community Lead – Contributor Engagement** – Grow and nurture the global contributor base.
# - **Security Analyst – FOSS Auditing** – Ensure cataloged projects meet high security & privacy standards.
#
# ### Our Culture in Action
# - **Hack Weeks** – Quarterly sprints where any team member can prototype new features.
# - **Open Governance** – Transparent decision‑making via public issue trackers and community voting.
# - **Diversity & Inclusion** – Active outreach to under‑represented groups in tech; scholarships for open‑source contributors.
#
# ---
#
# ## **Get Started with FOSS Systems**
#
# | Action | How |
# |--------|-----|
# | **Explore the Catalog** | Visit **[foss.systems/catalog](https://www.foss.systems/catalog)** and apply filters to find the perfect solution. |
# | **Read the Blog** | Stay current with trends and the **Federated Architecture Vision** at **[foss.systems/blog](https://www.foss.systems/blog)**. |
# | **Contribute** | Submit projects, improve data, or map connections via the **Contribute** portal. |
# | **Partner or License** | Contact the business development team for API access, data licensing, or sponsorship opportunities. |
# | **Join the Team** | Review open roles on the **Careers** page and become part of the open‑source revolution. |
#
# ---
#
# ### **Connect with Us**
# - **Website:** https://www.foss.systems
# - **Email:** info@foss.systems
# - **Community Forum:** Linked from the website footer
# - **Social:** Follow @FOSSsystems on Twitter, LinkedIn, and Mastodon for updates.
#
# ---
#
# *FOSS Systems – Empowering a free digital future, one open‑source project at a time.*
