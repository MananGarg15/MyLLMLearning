# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from Day5CompanyBrochure.Brochure import getBrochure

# %%
getBrochure('https://www.foss.systems/catalog/',company_name='foss systems',source='openRouter')
# Out:
# selecting relevant links from https://www.foss.systems/catalog/ using openRouter
# Found 10 relevant links
# Generated Brochure Content.
# Creating brochure for foss systems...
# # FOSS.systems: Powering the Future on Free & Open Source Software
#
# **A Central Hub for the World's Free Digital Infrastructure**
#
# ---
#
# ### **Company Overview: Our Mission in a Free Digital World**
#
# FOSS.systems is revolutionizing how the global community accesses and utilizes Free and Open Source Software (FOSS). We are not just a directory; we are the central, comprehensive repository that connects users to the building blocks of a truly free digital economy.
#
# *   **The Core Belief:** We believe that FOSS is the fundamental foundation for human freedom in the digital age. Open Source principles ensure that foundational technology remains accessible, adaptable, and controlled by its users, not by proprietary interests.
# ...

# %%
from Day5CompanyBrochure.HindiBrochure import hindiBrochure

# %%
hindiBrochure('https://huggingface.co/','Hugging Face')
# Out:
# selecting relevant links from https://huggingface.co/ using ollama
# Found 12 relevant links
# Generated Brochure Content.
# Creating brochure for Hugging Face...
# Brochure generated!
# Translating brochure in Hindi...
# # Hugging Face: कृत्रिम बुद्धिमत्ता के भविष्य का नेतृत्व करना
#
# **मशीन लर्निंग सहयोग का केंद्र बिंदु — जहाँ नवाचार वैश्विक पैमाने से मिलता है।**
#
# हगिंग फेस (Hugging Face) वह वैश्विक मंच है जो मशीन लर्निंग के जीवनचक्र को संचालित करता है। हम न केवल कोड देते हैं, बल्कि संपूर्ण पारिस्थितिकी तंत्र (Ecosystem) प्रदान करते हैं।
#
# ---
#
# ### 💡 हिन्दी सारांशण
#
# हमारा प्लेटफ़ॉर्म शोधकर्ताओं से लेकर बड़ी कंपनियों तक सभी के लिए एक व्यापक समाधान है, जो AI मॉडल के निर्माण, प्रशिक्षण और डिप्लॉयमेंट की पूरी प्रक्रिया को सरल और सुलभ बनाता है।
#
# ---
#
# ### 🚀 प्रमुख स्तंभ (Core Pillars)
#
# #### 1. मॉडल हब (The Model Hub)
# ...

# %%
getBrochure('https://edwarddonner.com/',source='gemini')
# Out:
# selecting relevant links from https://edwarddonner.com/ using gemini
# Found 9 relevant links
# Generated Brochure Content.
# Creating brochure for ...
# # Revolutionizing Talent and AI Proficiency: Introducing Nebula.io
#
# **(Note: This brochure is written for the umbrella entity, Nebula.io, leveraging the deep technical expertise and proven track record of its founder, Edward Donner.)**
#
# Welcome to the nexus of Artificial Intelligence and Human Potential. We are building the future of work, transforming how talent is discovered, managed, and optimized. From groundbreaking AI platforms to industry-leading educational curricula, our mission is to elevate human prosperity by connecting people to their ultimate calling.
#
# ***
#
# ### **Company Overview: Defining Purpose in the Age of AI**
#
# ...

# %%
hindiBrochure('https://huggingface.co/','Hugging Face')
# Out:
# selecting relevant links from https://huggingface.co/ using ollama
# Found 14 relevant links
# Generated Brochure Content.
# Creating brochure for Hugging Face...
# Brochure generated!
# Translating brochure in Hindi...
# # Hugging Face
# **भविष्य का निर्माण करने वाला एआई समुदाय**
#
# ---
#
# ## कंपनी का अवलोकन
# Hugging Face विश्व का प्रमुख ओपन‑सोर्स हब है जो सभी मशीन लर्निंग से संबंधित कार्यों के लिये समर्पित है। इसका मूल एक सहयोगी प्लेटफ़ॉर्म है जहाँ शोधकर्ता, डेवलपर और उद्यम नवीनतम मॉडल, डेटा सेट और एप्लिकेशन बना, खोज और परिनियोजित (deploy) कर सकते हैं।
# - **स्थापना**: 2016 (NYC)
# - **उद्देश्य**: “कृत्रिम बुद्धिमत्ता को लोकतंत्रीकृत करना, एक वैश्विक ओपन इकोसिस्टम बनाकर।”
# - **संचालन**: 2 + मिलियन मॉडल, 500 k+ डेटा सेट, 1 M+ एप्लिकेशन, 50 000+ संस्थाएँ Hugging Face टूल्स का उपयोग करती हैं।
# - **साझेदारी**: गूगल, अमेज़न, माइक्रोसॉफ्ट, मेटा, इंटेल और कई ओपन‑सोर्स प्रोजेक्ट्स के साथ सक्रिय सहयोग।
#
# ---
#
# ## उत्पाद व सेवाएँ
#
# | श्रेणी | यह क्या करता है | प्रमुख विशेषताएँ |
# ...
