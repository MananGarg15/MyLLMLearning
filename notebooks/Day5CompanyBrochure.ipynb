# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from Day5CompanyBrochure.Brochure import getBrochure

# %%
getBrochure('https://www.foss.systems/catalog/',company_name='foss systems',source='openRouter')

# %%
from Day5CompanyBrochure.HindiBrochure import hindiBrochure

# %%
hindiBrochure('https://huggingface.co/','Hugging Face')
# Out:
# selecting relevant links from https://huggingface.co/
# Found 17 relevant links
# Generated Brochure Content.
# Creating brochure for Hugging Face...
# Brochure generated!
# Translating brochure in Hindi...
# # हगिंग फेस: साथ मिलकर AI का भविष्य बनाना
#
# हगिंग फेस दुनिया का अग्रणी सहयोगात्मक मंच है जो पूरी मशीन लर्निंग जीवनचक्र (Machine Learning Lifecycle) को शक्ति प्रदान करता है—चाहे वह ओपन-सोर्स अनुसंधान हो, डेटा का क्यूरेशन हो, या उद्यम-स्तरीय (enterprise-grade) परिनियोजन (deployment) हो। हम वह केंद्रीय केंद्र हैं जहाँ डेवलपर्स, शोधकर्ता और व्यवसाय मिलकर अगली पीढ़ी के आर्टिफिशियल इंटेलिजेंस (AI) का निर्माण, साझाकरण और विस्तार करते हैं।
#
# ---
#
# **हमारा दृष्टिकोण (Our Vision):** एक खुला, सार्वभौमिक मंच बनाना जहाँ AI समुदाय को टेक्स्ट, इमेज, वीडियो, ऑडियो, और 3D सहित सभी माध्यमों में अत्याधुनिक AI मॉडल का निर्माण, पता लगाना और उपयोग (deploy) करना संभव हो।
#
# ---
#
# ### **✨ कंपनी अवलोकन: AI सहयोग मंच**
#
# हगिंग फेस आधुनिक AI क्रांति के लिए एक संचलन आधार (operational foundation) के रूप में कार्य करता है। हम एक एकीकृत, सुलभ इकोसिस्टम प्रदान करते हैं जिसे नवाचार को गति देने के लिए डिज़ाइन किया गया है, और यह अनुसंधान तथा उत्पादन के बीच के अंतर को पाटना है।
#
# ---
#
# ### **प्रमुख क्षेत्र (Key Areas)**
#
# **🔬 शोध और नवाचार (Research & Innovation):**
# उद्योग-अग्रणी टूल्स और मॉडल तक पहुंच प्रदान करता है, जिससे शोधकर्ताओं को जटिल समस्याओं पर काम करने में मदद मिलती है।
#
# **📈 स्केलेबिलिटी और विश्वसनीयता (Scalability & Reliability):**
# बड़े पैमाने पर कंप्यूटिंग और डेटा प्रबंधन के लिए विश्वसनीय इंफ्रास्ट्रक्चर प्रदान करता है, जिससे परियोजनाओं को स्थिरता मिलती है।
#
# **☁️ क्लाउड-आधारित समाधान (Cloud-Based Solutions):**
# किसी भी स्थान से पहुँचने योग्य और प्रबंधनीय AI कार्यभार की सुविधा देता है, जिससे वैश्विक टीमें समन्वय कर पाती हैं।
#
# ---
#
# ### **मुख्य स्तंभ (Core Pillars) - (यह अनुभाग सामग्री की गहराई को दर्शाता है)**
#
# **🛠️ टूलकिट और एपीआई (Toolkits & APIs):**
# सतत विकास (Continuous Development) के लिए पूर्व-निर्मित लाइब्रेरी और आसान इंटरफ़ेस प्रदान करता है।
#
# **💼 एंटरप्राइज सपोर्ट (Enterprise Support):**
# कस्टम समाधानों के लिए वन-ऑन-वन तकनीकी सहायता और सुरक्षा अनुपालन प्रदान करता है।
#
# **📚 कम्युनिटी और रिसोर्सेज (Community & Resources):**
# वैश्विक विशेषज्ञों और सहकर्मियों का एक विशाल नेटवर्क प्रदान करता है जो ज्ञान का आदान-प्रदान करते हैं।
#
# ---
#
# ### **संक्षेप में लाभ (Summary Benefits)**
#
# *   **तेजी से बाजार में पहुँच (Faster Time-to-Market):** प्रोटोटाइप को तेज़ी से वास्तविक उत्पाद में बदलें।
# *   **कम लागत (Cost Efficiency):** महंगे हार्डवेयर और मैनपावर की आवश्यकता को कम करें।
# *   **सिमेंटिक समझ (Semantic Understanding):** जटिल डेटा पैटर्न को समझने और कार्रवाई योग्य अंतर्दृष्टि निकालने की क्षमता।
# '# हगिंग फेस: साथ मिलकर AI का भविष्य बनाना\n\nहगिंग फेस दुनिया का अग्रणी सहयोगात्मक मंच है जो पूरी मशीन लर्निंग जीवनचक्र (Machine Learning Lifecycle) को शक्ति प्रदान करता है—चाहे वह ओपन-सोर्स अनुसंधान हो, डेटा का क्यूरेशन हो, या उद्यम-स्तरीय (enterprise-grade) परिनियोजन (deployment) हो। हम वह केंद्रीय केंद्र हैं जहाँ डेवलपर्स, शोधकर्ता और व्यवसाय मिलकर अगली पीढ़ी के आर्टिफिशियल इंटेलिजेंस (AI) का निर्माण, साझाकरण और विस्तार करते हैं।\n\n---\n\n**हमारा दृष्टिकोण (Our Vision):** एक खुला, सार्वभौमिक मंच बनाना जहाँ AI समुदाय को टेक्स्ट, इमेज, वीडियो, ऑडियो, और 3D सहित सभी माध्यमों में अत्याधुनिक AI मॉडल का निर्माण, पता लगाना और उपयोग (deploy) करना संभव हो।\n\n---\n\n### **✨ कंपनी अवलोकन: AI सहयोग मंच**\n\nहगिंग फेस आधुनिक AI क्रांति के लिए एक संचलन आधार (operational foundation) के रूप में कार्य करता है। हम एक एकीकृत, सुलभ इकोसिस्टम प्रदान करते हैं जिसे नवाचार को गति देने के लिए डिज़ाइन किया गया है, और यह अनुसंधान तथा उत्पादन के बीच के अंतर को पाटना है।\n\n---\n\n### **प्रमुख क्षेत्र (Key Areas)**\n\n**🔬 शोध और नवाचार (Research & Innovation):**\nउद्योग-अग्रणी टूल्स और मॉडल तक पहुंच प्रदान करता है, जिससे शोधकर्ताओं को जटिल समस्याओं पर काम करने में मदद मिलती है।\n\n**📈 स्केलेबिलिटी और विश्वसनीयता (Scalability & Reliability):**\nबड़े पैमाने पर कंप्यूटिंग और डेटा प्रबंधन के लिए विश्वसनीय इंफ्रास्ट्रक्चर प्रदान करता है, जिससे परियोजनाओं को स्थिरता मिलती है।\n\n**☁️ क्लाउड-आधारित समाधान (Cloud-Based Solutions):**\nकिसी भी स्थान से पहुँचने योग्य और प्रबंधनीय AI कार्यभार की सुविधा देता है, जिससे वैश्विक टीमें समन्वय कर पाती हैं।\n\n---\n\n### **मुख्य स्तंभ (Core Pillars) - (यह अनुभाग सामग्री की गहराई को दर्शाता है)**\n\n**🛠️ टूलकिट और एपीआई (Toolkits & APIs):**\nसतत विकास (Continuous Development) के लिए पूर्व-निर्मित लाइब्रेरी और आसान इंटरफ़ेस प्रदान करता है।\n\n**💼 एंटरप्राइज सपोर्ट (Enterprise Support):**\nकस्टम समाधानों के लिए वन-ऑन-वन तकनीकी सहायता और सुरक्षा अनुपालन प्रदान करता है।\n\n**📚 कम्युनिटी और रिसोर्सेज (Community & Resources):**\nवैश्विक विशेषज्ञों और सहकर्मियों का एक विशाल नेटवर्क प्रदान करता है जो ज्ञान का आदान-प्रदान करते हैं।\n\n---\n\n### **संक्षेप में लाभ (Summary Benefits)**\n\n*   **तेजी से बाजार में पहुँच (Faster Time-to-Market):** प्रोटोटाइप को तेज़ी से वास्तविक उत्पाद में बदलें।\n*   **कम लागत (Cost Efficiency):** महंगे हार्डवेयर और मैनपावर की आवश्यकता को कम करें।\n*   **सिमेंटिक समझ (Semantic Understanding):** जटिल डेटा पैटर्न को समझने और कार्रवाई योग्य अंतर्दृष्टि निकालने की क्षमता।'
