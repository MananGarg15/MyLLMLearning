# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from scraperTest import scrape_text
from getMessage import message_for
from IPython.display import Markdown, display
load_dotenv(override=True)
# Out:
# True

# %%
GEMINI_BASE_URL ="https://generativelanguage.googleapis.com/v1beta/openai/"
api_key = os.getenv("GOOGLE_API_KEY")

gemini = OpenAI(base_url=GEMINI_BASE_URL,api_key=api_key)

# %%
text = scrape_text("https://edwarddonner.com/")
text
# Out:
# 'Home - Edward Donner Home AI Curriculum Proficient AI Engineer Connect Four Outsmart An arena that pits LLMs against each other in a battle of diplomacy and deviousness About Posts Well, hi there. I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production ( very amateur) and losing myself in Hacker News , nodding my head sagely to things I only half understand. I’m the co-founder and CTO of Nebula.io . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt, acquired in 2021 . I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 400,000 enrolled across 1
# ...

# %%
messages = message_for("https://edwarddonner.com/")

# %%
response = gemini.chat.completions.create(model="gemini-3-flash-preview",
messages=messages)

# %%
display(Markdown(response.choices[0].message.content))
# Out:
# (Tap mic) Is this on?
#
# So I was checking out Ed Donner’s site. Ed is a big AI guy, but he admits he spends his time on Hacker News “nodding sagely to things he only half understands.” Finally! An honest tech guy! Most of us just squint at the screen and hope the word "Kubernetes" goes away if we ignore it long enough.
#
# Ed says his friends got so tired of him "droning on" about LLMs that they forced him to make Udemy courses. That’s the most polite intervention I’ve ever heard. “Ed, we love you, but please, go talk to 400,000 strangers so we can finally watch the game in peace.”
#
# But here’s the scary part: His blog posts are dated 2026. Ed’s a time traveler! And what is he doing in the future? He’s building an arena where AI models use "deviousness" to play Connect Four.
#
# ...
